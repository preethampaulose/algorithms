# %% [markdown]
# Loops may achieve a performance gain for your program. Recursion may achieve a performance gain for your programmer. Choose which is more important in your situation!

# %%
def fact(x):
  if x == 1:
    return 1
  else:
    return x * fact(x-1)

print(fact(5))
# Out:
# 120

# %% [markdown]
# ![fact1.jpg](attachment:fact1.jpg)

# %% [markdown]
# ![fact2.jpg](attachment:fact2.jpg)

# %% [markdown]
# #### Max in an array

# %%
def find_max(arr):
    if len(arr) == 2:
        return arr[0] if arr[0] > arr[1] else arr[1]
    sub_max = find_max(arr[1:])
    return arr[0] if arr[0] > sub_max else sub_max

# %%
print(find_max([1,3,2,6,4,5,1,7,8,9,12,2,3,1]))
# Out:
# 12

# %% [markdown]
# #### Sum of array

# %%
def sum_array(arr):
    if not arr:
        return 0
    return arr[0] + sum_array(arr[1:])

# %%
print(sum_array([1,4,3]))
# Out:
# 8

# %% [markdown]
# #### Count

# %%
def count(list):
  if list == []:
    return 0
  return 1 + count(list[1:])

# %%
print(count([1,2,5,2,4,3]))
# Out:
# 6
